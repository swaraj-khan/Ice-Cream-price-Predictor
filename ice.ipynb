# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
IceCream = pd.read_csv("IceCreamData.csv")
IceCream.head()
IceCream.tail()
IceCream.describe()
IceCream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
sns.jointplot(x='Temperature', y='Revenue', data = IceCream)
sns.pairplot(IceCream)
sns.lmplot(x='Temperature', y='Revenue', data=IceCream)

# %%
y = IceCream['Revenue']
X = IceCream[['Temperature']]

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.shape

from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept =True)
regressor.fit(X_train,y_train)

print('Linear Model Coefficient (m): ', regressor.coef_)
print('Linear Model Coefficient (b): ', regressor.intercept_)
# Out:
# Linear Model Coefficient (m):  [21.40869146]
# Linear Model Coefficient (b):  46.40571910253891

# %%
y_predict = regressor.predict( X_test)
y_predict
y_test
# Out:
# 118    306.749930
# 69     430.343903
# 9      737.800824
# 231    449.112869
# 304    714.560056
#           ...
# 461    636.298374
# 82     515.459102
# 469    489.569090
# 114    385.672501
# 448    629.893792
# Name: Revenue, Length: 125, dtype: float64

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated vs. Temperature @Ice Cream Stand(Training dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @Ice Cream Stand(Training dataset)')

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_test, regressor.predict(X_test), color = 'blue')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Hours')
plt.title('Revenue Generated vs. Hours @Ice Cream Stand(Test dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Hours @Ice Cream Stand(Test dataset)')

# %%
import numpy as np

y_predict = regressor.predict(np.array(30).reshape(-1, 1))
print(y_predict)
# Out:
# [688.66646299]
# c:\Users\Swaraj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
